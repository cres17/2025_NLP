# %% [markdown]
# <a href="https://colab.research.google.com/github/cres17/2025_NLP/blob/main/%5B%EC%A7%80%EB%8A%A5%ED%98%95SW%5D_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 2.8.1
#     Uninstalling openai-2.8.1:
#       Successfully uninstalled openai-2.8.1
# ...

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
import openai
import requests
from PIL import Image
from io import BytesIO

openai.api_key = OPENAI_API_KEY

def generate_image(prompt):
  response = openai.Image.create(
      prompt=prompt,
      n=1,
      size="1024x1024"
  )
  image_url = response['data'][0]['url']
  return image_url

def save_image(image_url, filename):
  response = requests.get(image_url)
  image = Image.open(BytesIO(response.content))
  image.save(filename)

# %%
prompt = "A cute black cat at night"

image_url = generate_image(prompt)
print(f"Image URL: {image_url}")

filename = "generated_image.png"
save_image(image_url, filename)
print("Image saved as generated_image.png")
# Out:
# Image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-LNZ1tavUAPmHVmwDyp31JqYM/user-QYxQFQw0ly2kYWSBvld2Ddzz/img-qAlUiz92pJ90ADlddq4yjgxM.png?st=2025-11-25T04%3A33%3A50Z&se=2025-11-25T06%3A33%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=f1dafa11-a0c2-4092-91d4-10981fbda051&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-11-25T05%3A33%3A50Z&ske=2025-11-26T05%3A33%3A50Z&sks=b&skv=2024-08-04&sig=FjX0QQlQH/lJFsf64axHZUM02kEd59r7OYjTXOJEzOw%3D
# Image saved as generated_image.png
