# %% [markdown]
# <a href="https://colab.research.google.com/github/cres17/2025_NLP/blob/main/%5B%EC%A7%80%EB%8A%A5%ED%98%95SW%5D_Moderation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai --upgrade

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
import openai
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)

# %%
def moderate_text(input_text):
  response = client.moderations.create(
      model = "omni-moderation-latest",
      input = input_text
  )
  return response

input_texts = [
    "I want to harm myself",
    "You are an amazing person",
    "Let's meet at 8PM.",
    "I hate you and I want to hurt you."
]

for text in input_texts:
  moderation_result = moderate_text(text)
  print(f"Input : {text}")
  print(f"Moderation result : {moderation_result}")
  print("-" * 40)
# Out:
# Input : I want to harm myself
# ...
